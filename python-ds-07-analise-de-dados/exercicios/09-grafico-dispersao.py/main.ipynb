# %%
from scipy.stats import alpha

print('I am becoming a man of value!')
# Out:
# I am becoming a man of value!

# %%
'''
    9) Gráficos de Dispersão: Crie um gráfico de dispersão (sns.scatterplot) relacionando duas variáveis e use o argumento hue para colorir os pontos de acordo com uma terceira variável categórica.
'''
# Out:
# '\n    9) Gráficos de Dispersão: Crie um gráfico de dispersão (sns.scatterplot) relacionando duas variáveis e use o argumento hue para colorir os pontos de acordo com uma terceira variável categórica.\n'

# %%
import seaborn as sns

df = sns.load_dataset('titanic')

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import matplotlib.pyplot as plt

# Criando o scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="age", y="fare", hue="survived", alpha=0.7)

plt.title("Relação entre Fare vs Age (Colorido por Survived)")
plt.show()

# %%
'''
    O gráfico mostra que o preço da passagem e a idade influenciaram a vida no Titanic. Passageiros que pagaram tarifas altas (topo) sobreviveram mais. Na base (tarifas baixas), a mortalidade foi maior, exceto entre crianças, evidenciando que o poder aquisitivo e a idade foram fatores decisivos.
'''
